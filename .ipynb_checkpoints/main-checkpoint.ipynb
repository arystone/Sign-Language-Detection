# %%
import cv2
import numpy as np
import os
from matplotlib import pyplot as plt
import time
import mediapipe as mp

# %%
mp_holistic = mp.solutions.holistic
mp_drawing = mp.solutions.drawing_utils

# %%
def mediapipe_detection(image, model):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image.flags.writeable = False
    results = model.process(image)
    image.flags.writeable = True
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
    return image, results

# %%
def draw_landmarks(image, results):
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION, 
                              mp_drawing.DrawingSpec(color=(0,255,0),thickness=1, circle_radius=1),
                             mp_drawing.DrawingSpec(color=(255,0,0), thickness=1, circle_radius=1))                            
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
                              mp_drawing.DrawingSpec(color=(0,255,0),thickness=2, circle_radius=3),
                             mp_drawing.DrawingSpec(color=(255,0,0), thickness=2, circle_radius=2))
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS,
                              mp_drawing.DrawingSpec(color=(188,0,255),thickness=2, circle_radius=3),
                             mp_drawing.DrawingSpec(color=(124,26,159), thickness=2, circle_radius=2))
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS,
                              mp_drawing.DrawingSpec(color=(255,43,0),thickness=2, circle_radius=3),
                             mp_drawing.DrawingSpec(color=(161,37,37), thickness=2, circle_radius=2))

# %%
cap = cv2.VideoCapture(0)

with mp_holistic.Holistic(min_detection_confidence=0.4, min_tracking_confidence=0.4) as holistic: 
    while cap.isOpened():
        ret, frame = cap.read()

        image, results = mediapipe_detection(frame, holistic)
#         print(results)
        
        draw_landmarks(image, results)

        cv2.imshow('ML Project', image)
        if(cv2.waitKey(10) & 0xFF == ord('p')):
            break
    cap.release()
    cv2.destroyAllWindows()

# %%
draw_landmarks(frame,results)

# %%
plt.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))

# %%
def extract_keypoints(results):
    pose = np.zeros(33*4)
    if results.pose_landmarks:
        pose=np.array([[res.x,res.y,res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten()
    
    lh = np.zeros(21*3)
    if results.left_hand_landmarks:
        lh = np.array([[res.x,res.y,res.z] for res in results.left_hand_landmarks.landmark]).flatten()
        
    rh=np.zeros(21*3)
    if results.right_hand_landmarks:
        rh = np.array([[res.x,res.y,res.z] for res in results.right_hand_landmarks.landmark]).flatten()
        
    face = np.zeros(468*3)
    if results.face_landmarks:
        face = np.array([[res.x,res.y,res.z] for res in results.face_landmarks.landmark]).flatten()
        
    return np.concatenate([pose, face, lh, rh])

# %%
extract_keypoints(results)[:-10]
# Out:
# array([ 0.47962409,  0.65295255, -1.59662092, ...,  0.        ,
#         0.        ,  0.        ])

# %%
DATA_PATH = os.path.join('MP_Data')

actions = np.array(['hello', 'thanks', 'iloveyou'])

no_sequences = 30
sequence_length = 30

# %%
for action in actions:
    for sequence in range(no_sequences):
        try:
            os.makedirs(os.path.join(DATA_PATH, action, str(sequence)))
        except: 
            pass

# %%
cap = cv2.VideoCapture(0)

with mp_holistic.Holistic(min_detection_confidence=0.4, min_tracking_confidence=0.4) as holistic: 
    
    for action in actions:
        for sequence in range(no_sequences):
            for frame_num in range(sequence_length):
    
                ret, frame = cap.read()

                image, results = mediapipe_detection(frame, holistic)

                draw_landmarks(image, results)

                if frame_num == 0:
                    cv2.putText(image, 'starting collection', (120,200), 
                                cv2.FONT_HERSHEY_SIMPLEX, 1, (0,255, 0), 4, cv2.LINE_AA)
                    cv2.putText(image, 'collecting frames for '+str(action)+' Video number '+ str(sequence), (15,12),
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0,0,255), 1, cv2.LINE_AA)
                    cv2.waitKey(1000)
                else:
                    cv2.putText(image, 'collecting frames for '+str(action)+' Video number '+ str(sequence), (15,12),
                                cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0,0,255), 1, cv2.LINE_AA)

                keypoints = extract_keypoints(results)
                npy_path = os.path.join(DATA_PATH, action, str(sequence), str(frame_num))
                np.save(npy_path, keypoints)
                    
                cv2.imshow('ML Project', image)
                if(cv2.waitKey(10) & 0xFF == ord('p')):
                    break
    cap.release()
    cv2.destroyAllWindows()

# %%
cap.release()
cv2.destroyAllWindows()

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# %%
label_map = {label: num for num, label in enumerate(actions)}

# %%
sequences, labels = [], []
for action in actions:
    for sequence in range(no_sequences):
        window = []
        for frame_num in range(sequence_length):
            res = np.load(os.path.join(DATA_PATH, action, str(sequence), "{}.npy".format(frame_num)))
            window.append(res)
        sequences.append(window)
        labels.append(label_map[action])

# %%
X = np.array(sequences)
y = to_categorical(labels).astype(int)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.05)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import TensorBoard

# %%
log_dir = os.path.join('LOGS')
tb_callback = TensorBoard(log_dir=log_dir)

# %%
model = Sequential()
model.add(LSTM(64, return_sequences=True, activation='relu', input_shape=(30, 1662)))
model.add(LSTM(128, return_sequences=True, activation='relu'))
model.add(LSTM(64, return_sequences=False, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(actions.shape[0], activation='softmax'))

# %%
res = [.7, .2, .1]

# %%
model.compile(optimizer='Adamax', loss='categorical_crossentropy', metrics=['categorical_accuracy'])

# %%
model.fit(X_train, y_train, epochs=100, callbacks=[tb_callback])
# Out:
# Epoch 1/100
# 3/3 [==============================] - 3s 59ms/step - loss: 1.4491 - categorical_accuracy: 0.3882
# Epoch 2/100
# 3/3 [==============================] - 0s 54ms/step - loss: 5.7535 - categorical_accuracy: 0.3294
# Epoch 3/100
# 3/3 [==============================] - 0s 55ms/step - loss: 1.1145 - categorical_accuracy: 0.3529
# Epoch 4/100
# 3/3 [==============================] - 0s 55ms/step - loss: 1.1072 - categorical_accuracy: 0.4118
# Epoch 5/100
# 3/3 [==============================] - 0s 55ms/step - loss: 1.1245 - categorical_accuracy: 0.3882
# Epoch 6/100
# 3/3 [==============================] - 0s 55ms/step - loss: 1.0121 - categorical_accuracy: 0.5059
# Epoch 7/100
# 3/3 [==============================] - 0s 55ms/step - loss: 0.9248 - categorical_accuracy: 0.5765
# Epoch 8/100
# 3/3 [==============================] - 0s 56ms/step - loss: 0.8460 - categorical_accuracy: 0.6471
# Epoch 9/100
# 3/3 [==============================] - 0s 57ms/step - loss: 0.8024 - categorical_accuracy: 0.6000
# Epoch 10/100
# 3/3 [==============================] - 0s 61ms/step - loss: 0.7445 - categorical_accuracy: 0.6588
# Epoch 11/100
# 3/3 [==============================] - 0s 55ms/step - loss: 0.7749 - categorical_accuracy: 0.6235
# Epoch 12/100
# 3/3 [==============================] - 0s 59ms/step - loss: 0.7106 - categorical_accuracy: 0.6706
# Epoch 13/100
# 3/3 [==============================] - 0s 57ms/step - loss: 0.7824 - categorical_accuracy: 0.5765
# Epoch 14/100
# 3/3 [==============================] - 0s 56ms/step - loss: 0.7182 - categorical_accuracy: 0.6588
# Epoch 15/100
# 3/3 [==============================] - 0s 55ms/step - loss: 0.6850 - categorical_accuracy: 0.6118
# Epoch 16/100
# 3/3 [==============================] - 0s 56ms/step - loss: 0.6543 - categorical_accuracy: 0.5882
# Epoch 17/100
# 3/3 [==============================] - 0s 59ms/step - loss: 0.5811 - categorical_accuracy: 0.7529
# Epoch 18/100
# 3/3 [==============================] - 0s 56ms/step - loss: 0.5678 - categorical_accuracy: 0.6941
# Epoch 19/100
# 3/3 [==============================] - 0s 57ms/step - loss: 0.5401 - categorical_accuracy: 0.7294
# Epoch 20/100
# 3/3 [==============================] - 0s 59ms/step - loss: 0.5267 - categorical_accuracy: 0.6941
# Epoch 21/100
# 3/3 [==============================] - 0s 58ms/step - loss: 0.5683 - categorical_accuracy: 0.6588
# Epoch 22/100
# 3/3 [==============================] - 0s 56ms/step - loss: 0.5348 - categorical_accuracy: 0.7176
# Epoch 23/100
# 3/3 [==============================] - 0s 56ms/step - loss: 0.4867 - categorical_accuracy: 0.8235
# Epoch 24/100
# 3/3 [==============================] - 0s 59ms/step - loss: 0.4578 - categorical_accuracy: 0.8588
# Epoch 25/100
# 3/3 [==============================] - 0s 59ms/step - loss: 0.4197 - categorical_accuracy: 0.8118
# Epoch 26/100
# 3/3 [==============================] - 0s 55ms/step - loss: 0.4740 - categorical_accuracy: 0.8000
# Epoch 27/100
# 3/3 [==============================] - 0s 56ms/step - loss: 0.3670 - categorical_accuracy: 0.8706
# Epoch 28/100
# 3/3 [==============================] - 0s 56ms/step - loss: 0.4234 - categorical_accuracy: 0.7882
# Epoch 29/100
# 3/3 [==============================] - 0s 56ms/step - loss: 0.3686 - categorical_accuracy: 0.8235
# Epoch 30/100
# 3/3 [==============================] - 0s 56ms/step - loss: 0.5332 - categorical_accuracy: 0.7882
# Epoch 31/100
# 3/3 [==============================] - 0s 55ms/step - loss: 0.4076 - categorical_accuracy: 0.8118
# Epoch 32/100
# 3/3 [==============================] - 0s 56ms/step - loss: 0.4185 - categorical_accuracy: 0.7882
# Epoch 33/100
# 3/3 [==============================] - 0s 56ms/step - loss: 0.5045 - categorical_accuracy: 0.7882
# Epoch 34/100
# 3/3 [==============================] - 0s 59ms/step - loss: 0.4821 - categorical_accuracy: 0.7176
# Epoch 35/100
# 3/3 [==============================] - 0s 58ms/step - loss: 0.3857 - categorical_accuracy: 0.8588
# Epoch 36/100
# 3/3 [==============================] - 0s 55ms/step - loss: 0.4556 - categorical_accuracy: 0.8471
# Epoch 37/100
# 3/3 [==============================] - 0s 56ms/step - loss: 0.7576 - categorical_accuracy: 0.7059
# Epoch 38/100
# 3/3 [==============================] - 0s 60ms/step - loss: 0.4913 - categorical_accuracy: 0.8000
# Epoch 39/100
# 3/3 [==============================] - 0s 58ms/step - loss: 0.8666 - categorical_accuracy: 0.6118
# Epoch 40/100
# 3/3 [==============================] - 0s 57ms/step - loss: 0.4263 - categorical_accuracy: 0.7412
# Epoch 41/100
# 3/3 [==============================] - 0s 57ms/step - loss: 0.6441 - categorical_accuracy: 0.6824
# Epoch 42/100
# 3/3 [==============================] - 0s 58ms/step - loss: 0.5423 - categorical_accuracy: 0.7765
# Epoch 43/100
# 3/3 [==============================] - 0s 60ms/step - loss: 0.4693 - categorical_accuracy: 0.7765
# Epoch 44/100
# 3/3 [==============================] - 0s 56ms/step - loss: 0.4462 - categorical_accuracy: 0.8235
# Epoch 45/100
# 3/3 [==============================] - 0s 56ms/step - loss: 0.4372 - categorical_accuracy: 0.7647
# Epoch 46/100
# 3/3 [==============================] - 0s 56ms/step - loss: 0.4899 - categorical_accuracy: 0.7647
# Epoch 47/100
# 3/3 [==============================] - 0s 58ms/step - loss: 0.4026 - categorical_accuracy: 0.7882
# Epoch 48/100
# 3/3 [==============================] - 0s 58ms/step - loss: 0.4118 - categorical_accuracy: 0.7647
# Epoch 49/100
# 3/3 [==============================] - 0s 60ms/step - loss: 0.4565 - categorical_accuracy: 0.7529
# Epoch 50/100
# 3/3 [==============================] - 0s 56ms/step - loss: 0.5173 - categorical_accuracy: 0.7882
# Epoch 51/100
# 3/3 [==============================] - 0s 58ms/step - loss: 0.4600 - categorical_accuracy: 0.7529
# Epoch 52/100
# 3/3 [==============================] - 0s 59ms/step - loss: 0.3513 - categorical_accuracy: 0.8588
# Epoch 53/100
# 3/3 [==============================] - 0s 59ms/step - loss: 0.4444 - categorical_accuracy: 0.7765
# Epoch 54/100
# 3/3 [==============================] - 0s 57ms/step - loss: 0.3586 - categorical_accuracy: 0.8706
# Epoch 55/100
# 3/3 [==============================] - 0s 57ms/step - loss: 0.3925 - categorical_accuracy: 0.8118
# Epoch 56/100
# 3/3 [==============================] - 0s 56ms/step - loss: 0.3671 - categorical_accuracy: 0.8824
# Epoch 57/100
# 3/3 [==============================] - 0s 60ms/step - loss: 0.3394 - categorical_accuracy: 0.8824
# Epoch 58/100
# 3/3 [==============================] - 0s 59ms/step - loss: 0.3269 - categorical_accuracy: 0.9294
# Epoch 59/100
# 3/3 [==============================] - 0s 56ms/step - loss: 0.3195 - categorical_accuracy: 0.8941
# Epoch 60/100
# 3/3 [==============================] - 0s 57ms/step - loss: 0.2866 - categorical_accuracy: 0.9294
# Epoch 61/100
# 3/3 [==============================] - 0s 59ms/step - loss: 0.3142 - categorical_accuracy: 0.8706
# Epoch 62/100
# 3/3 [==============================] - 0s 56ms/step - loss: 0.2404 - categorical_accuracy: 0.9294
# Epoch 63/100
# 3/3 [==============================] - 0s 56ms/step - loss: 0.2184 - categorical_accuracy: 0.9176
# Epoch 64/100
# 3/3 [==============================] - 0s 61ms/step - loss: 0.2008 - categorical_accuracy: 0.9412
# Epoch 65/100
# 3/3 [==============================] - 0s 60ms/step - loss: 0.2726 - categorical_accuracy: 0.8824
# Epoch 66/100
# 3/3 [==============================] - 0s 57ms/step - loss: 0.2938 - categorical_accuracy: 0.8824
# Epoch 67/100
# 3/3 [==============================] - 0s 56ms/step - loss: 0.2733 - categorical_accuracy: 0.8706
# Epoch 68/100
# 3/3 [==============================] - 0s 57ms/step - loss: 0.4233 - categorical_accuracy: 0.8118
# Epoch 69/100
# 3/3 [==============================] - 0s 57ms/step - loss: 0.4996 - categorical_accuracy: 0.7529
# Epoch 70/100
# 3/3 [==============================] - 0s 61ms/step - loss: 0.6344 - categorical_accuracy: 0.8118
# Epoch 71/100
# 3/3 [==============================] - 0s 56ms/step - loss: 0.3965 - categorical_accuracy: 0.7765
# Epoch 72/100
# 3/3 [==============================] - 0s 58ms/step - loss: 0.2869 - categorical_accuracy: 0.9294
# Epoch 73/100
# 3/3 [==============================] - 0s 56ms/step - loss: 0.4069 - categorical_accuracy: 0.8353
# Epoch 74/100
# 3/3 [==============================] - 0s 60ms/step - loss: 0.3501 - categorical_accuracy: 0.8824
# Epoch 75/100
# 3/3 [==============================] - 0s 57ms/step - loss: 0.2739 - categorical_accuracy: 0.9176
# Epoch 76/100
# 3/3 [==============================] - 0s 57ms/step - loss: 0.2954 - categorical_accuracy: 0.9059
# Epoch 77/100
# 3/3 [==============================] - 0s 60ms/step - loss: 0.2391 - categorical_accuracy: 0.9412
# Epoch 78/100
# 3/3 [==============================] - 0s 59ms/step - loss: 0.2274 - categorical_accuracy: 0.9412
# Epoch 79/100
# 3/3 [==============================] - 0s 59ms/step - loss: 0.2130 - categorical_accuracy: 0.9412
# Epoch 80/100
# 3/3 [==============================] - 0s 60ms/step - loss: 0.2029 - categorical_accuracy: 0.9412
# Epoch 81/100
# 3/3 [==============================] - 0s 58ms/step - loss: 0.1988 - categorical_accuracy: 0.9176
# Epoch 82/100
# 3/3 [==============================] - 0s 58ms/step - loss: 0.2509 - categorical_accuracy: 0.9059
# Epoch 83/100
# 3/3 [==============================] - 0s 60ms/step - loss: 0.1658 - categorical_accuracy: 0.9529
# Epoch 84/100
# 3/3 [==============================] - 0s 59ms/step - loss: 0.1533 - categorical_accuracy: 0.9412
# Epoch 85/100
# 3/3 [==============================] - 0s 56ms/step - loss: 0.1535 - categorical_accuracy: 0.9412
# Epoch 86/100
# 3/3 [==============================] - 0s 60ms/step - loss: 0.1617 - categorical_accuracy: 0.9412
# Epoch 87/100
# 3/3 [==============================] - 0s 56ms/step - loss: 0.1503 - categorical_accuracy: 0.9412
# Epoch 88/100
# 3/3 [==============================] - 0s 57ms/step - loss: 0.1467 - categorical_accuracy: 0.9529
# Epoch 89/100
# 3/3 [==============================] - 0s 62ms/step - loss: 0.1369 - categorical_accuracy: 0.9529
# Epoch 90/100
# 3/3 [==============================] - 0s 59ms/step - loss: 0.1340 - categorical_accuracy: 0.9412
# Epoch 91/100
# 3/3 [==============================] - 0s 57ms/step - loss: 0.1347 - categorical_accuracy: 0.9294
# Epoch 92/100
# 3/3 [==============================] - 0s 60ms/step - loss: 0.1445 - categorical_accuracy: 0.9294
# Epoch 93/100
# 3/3 [==============================] - 0s 58ms/step - loss: 0.1025 - categorical_accuracy: 0.9765
# Epoch 94/100
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0996 - categorical_accuracy: 0.9647
# Epoch 95/100
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0951 - categorical_accuracy: 0.9647
# Epoch 96/100
# 3/3 [==============================] - 0s 59ms/step - loss: 0.1360 - categorical_accuracy: 0.9294
# Epoch 97/100
# 3/3 [==============================] - 0s 56ms/step - loss: 0.3302 - categorical_accuracy: 0.8706
# Epoch 98/100
# 3/3 [==============================] - 0s 56ms/step - loss: 0.2108 - categorical_accuracy: 0.8941
# Epoch 99/100
# 3/3 [==============================] - 0s 60ms/step - loss: 0.2578 - categorical_accuracy: 0.8824
# Epoch 100/100
# 3/3 [==============================] - 0s 57ms/step - loss: 0.2628 - categorical_accuracy: 0.8824

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 30, 64)            442112
#
#  lstm_1 (LSTM)               (None, 30, 128)           98816
#
#  lstm_2 (LSTM)               (None, 64)                49408
#
#  dense (Dense)               (None, 64)                4160
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 3)                 99
#
# =================================================================
# Total params: 596,675
# Trainable params: 596,675
# Non-trainable params: 0
# _________________________________________________________________

# %%
res = model.predict(X_test)
# Out:
# 1/1 [==============================] - 0s 334ms/step

# %%
model.save('action.h5')

# %%
from sklearn.metrics import multilabel_confusion_matrix, accuracy_score

# %%
yhat = model.predict(X_test)
# Out:
# 1/1 [==============================] - 0s 27ms/step

# %%
ytrue = np.argmax(y_test, axis=1).tolist()
yhat = np.argmax(yhat, axis=1).tolist()

# %%
multilabel_confusion_matrix(ytrue, yhat)
# Out:
# array([[[1, 1],
#         [0, 3]],
#
#        [[3, 0],
#         [1, 1]]], dtype=int64)

# %%
accuracy_score(ytrue, yhat)
# Out:
# 0.8

# %%
sequence = []
sentence = []
threshold = .4

cap = cv2.VideoCapture(0)

with mp_holistic.Holistic(min_detection_confidence=0.4, min_tracking_confidence=0.4) as holistic: 
    while cap.isOpened():
        ret, frame = cap.read()

        image, results = mediapipe_detection(frame, holistic)
        
        draw_landmarks(image, results)

        keypoints = extract_keypoints(results)
        sequence.insert(0,keypoints)
        sequence = sequence[:30]
        
        if len(sequence) == 30:
            res = model.predict(np.expand_dims(sequence, axis=0))[0]

            if res[np.argmax(res)] > threshold: 
                if len(sentence) > 0: 
                    if actions[np.argmax(res)] != sentence[-1]:
                        sentence = (actions[np.argmax(res)])
                else:
                    sentence.append(actions[np.argmax(res)])

            if len(sentence) > 5: 
                sentence = sentence[-5:]

        
        cv2.rectangle(image, (0, 0), (640, 40), (245, 300, 16), -1)
        cv2.putText(image, ''.join(sentence), (5,30), 
                    cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
        
        cv2.imshow('ML Project', image)
        if(cv2.waitKey(10) & 0xFF == ord('p')):
            break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step

# %%
model.predict(np.expand_dims(X_test[0], axis=1))
# Out:
# 1/1 [==============================] - 0s 21ms/step
# array([[0.3270056 , 0.3412663 , 0.33172807],
#        [0.32724822, 0.34099627, 0.33175546],
#        [0.3272451 , 0.3409976 , 0.33175725],
#        [0.32696956, 0.34130132, 0.33172905],
#        [0.3269768 , 0.3413005 , 0.33172277],
#        [0.32696852, 0.34130284, 0.3317287 ],
#        [0.32696468, 0.3412981 , 0.3317372 ],
#        [0.32696018, 0.3412993 , 0.33174047],
#        [0.3269581 , 0.34130877, 0.3317331 ],
#        [0.32694626, 0.34130198, 0.33175173],
#        [0.3269436 , 0.34130597, 0.33175045],
#        [0.32694438, 0.34130657, 0.33174914],
#        [0.3269331 , 0.34131372, 0.33175316],
#        [0.32693458, 0.34131357, 0.3317518 ],
#        [0.32693326, 0.34131548, 0.3317513 ],
#        [0.3269346 , 0.3413142 , 0.3317512 ],
#        [0.32693163, 0.3413144 , 0.33175394],
#        [0.32692087, 0.34132436, 0.33175477],
#        [0.32688797, 0.341358  , 0.331754  ],
#        [0.326889  , 0.34135598, 0.331755  ],
#        [0.32700738, 0.34126624, 0.3317264 ],
#        [0.32699752, 0.34129152, 0.331711  ],
#        [0.32702324, 0.34125796, 0.33171883],
#        [0.32699698, 0.34128258, 0.33172044],
#        [0.3269974 , 0.34128064, 0.3317219 ],
#        [0.3269935 , 0.34128585, 0.33172068],
#        [0.3270049 , 0.34126836, 0.33172667],
#        [0.32702044, 0.34124097, 0.3317386 ],
#        [0.32702136, 0.3412392 , 0.3317394 ],
#        [0.32730737, 0.34091443, 0.3317782 ]], dtype=float32)
